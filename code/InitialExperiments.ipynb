# %%
import os
import numpy as np
import torch
import matplotlib.pyplot as plt

from IPython.display import Image

# %%
path = "/projectnb/labci/Lucia/rainfall-pde-ml/experiments/2023-09-26/"

# %% [markdown]
# # Load training & validation losses

# %%
noreg_train = np.load(path + "BezenacSqErr_100/train_losses.npy")
noreg_val = np.load(path + "BezenacSqErr_100/val_losses.npy")

reg_train = np.load(path + "BezenacRegSqErr_100/train_losses.npy")
reg_val = np.load(path + "BezenacRegSqErr_100/val_losses.npy")

# %%
plt.plot(noreg_train, linestyle="solid", color="blue")
plt.plot(noreg_val, linestyle="solid", color="orange")
plt.plot(reg_train, linestyle="dotted", color="blue")
plt.plot(reg_train, linestyle="dotted", color="orange")

plt.ylabel("Loss")
plt.xlabel("Epochs")

plt.legend(["NoReg, Training", "NoReg, Val", "Reg, Training", "Reg, Val"])
plt.title("Model Loss Comparison")
# Out:
# Text(0.5, 1.0, 'Model Loss Comparison')

# %%
print("NoReg mean loss:", np.mean(noreg_train))
print("Reg mean loss:  ", np.mean(reg_train))
# Out:
# NoReg mean loss: 1.7830526
# Reg mean loss:   1.3100427

# %%
noreg_train = np.load(path + )
reg_train = np.load()

noreg_val = np.load()
reg_val = np.load()

# %% [markdown]
# # Load saved images

# %%
Image(path + "imageComparison.png")
